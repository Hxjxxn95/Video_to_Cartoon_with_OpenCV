# %%
import cv2
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

def cartoonize(frame):

    # 그레이스케일로 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 중간 톤 제거
    gray = cv2.medianBlur(gray, 5)

    # Canny 엣지 감지
    edges = cv2.Canny(gray, 50, 150)

    # 엣지 반전
    edges = cv2.bitwise_not(edges)

    # 컬러 이미지에 bilateral filter 적용
    color = cv2.bilateralFilter(frame, 9, 500, 1200)

    # 엣지와 컬러 이미지 합치기
    cartoon = cv2.bitwise_and(color, color, mask=edges)
    
    return cartoon
    

def best_cartoonize(video):

    gray = cv2.cvtColor(video, cv2.COLOR_BGR2GRAY)

    gray = cv2.medianBlur(gray, 5)

    edges = cv2.Canny(gray, 40, 100)

    edges = cv2.bitwise_not(edges)

    color = cv2.bilateralFilter(video, 9, 400, 1200)

    pixel_values = color.reshape((-1, 3))

    kmeans = KMeans(n_clusters=20)
    labels = kmeans.fit_predict(pixel_values)

    centers = kmeans.cluster_centers_
    segmented_image = centers[labels].reshape(color.shape).astype('uint8')

    cartoon = cv2.bitwise_and(segmented_image, segmented_image, mask=edges)
    
    return cartoon

# %%
cap = cv2.VideoCapture('video.mp4')

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
out = cv2.VideoWriter('bad.mp4', fourcc, fps, (frame_width, frame_height))


frames_to_process = int(5 * fps)

frame_counter = 0
while(cap.isOpened() and frame_counter < frames_to_process):
    ret, frame = cap.read()
    if ret==True:
        # 모든 10프레임마다 하나씩 처리
        if frame_counter % 10 == 0:
            frame = cartoonize(frame)
            out.write(frame)
        frame_counter += 1
    else:
        break

# 작업 완료 후 해제
cap.release()
out.release()

# %%
# 비디오 읽기
cap = cv2.VideoCapture('video.mp4')

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
out = cv2.VideoWriter('output.mp4', fourcc, fps, (frame_width, frame_height))

frames_to_process = int(5 * fps)

frame_counter = 0
while(cap.isOpened() and frame_counter < frames_to_process):
    ret, frame = cap.read()
    if ret==True:
        # 모든 10프레임마다 하나씩 처리
        if frame_counter % 10 == 0:
            frame = best_cartoonize(frame)
            out.write(frame)
        frame_counter += 1
    else:
        break

# 작업 완료 후 해제
cap.release()
out.release()
# Out:
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/hojoonkim/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
